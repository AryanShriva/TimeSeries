# %%
# !pip install yfinance

import numpy as np
import pandas as pd
import yfinance as yfin
import pandas_datareader as pdr
yfin.pdr_override()

data = yfin.download('TSLA')
# Out:
# Requirement already satisfied: yfinance in c:\users\arya shriva\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: requests>=2.26 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (3.4.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\arya shriva\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arya shriva\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\arya shriva\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\arya shriva\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.20)
# Requirement already satisfied: six>=1.9 in c:\users\arya shriva\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\arya shriva\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\arya shriva\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\arya shriva\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arya shriva\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arya shriva\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arya shriva\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# [*********************100%***********************]  1 of 1 completed

# %%
df_tesla=data

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
# 2023-01-10  121.070000  122.760002  114.919998  118.849998  118.849998
# 2023-01-11  122.089996  125.949997  120.510002  123.220001  123.220001
# 2023-01-12  122.559998  124.129997  117.000000  123.559998  123.559998
# 2023-01-13  116.550003  122.629997  115.599998  122.400002  122.400002
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# 2010-07-02   77097000
# 2010-07-06  103003500
# ...               ...
# 2023-01-09  190284000
# 2023-01-10  167642500
# 2023-01-11  183810800
# 2023-01-12  169400900
# 2023-01-13  180439300
#
# [3159 rows x 6 columns]

# %%
df_tesla.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# simple Moving Average

# %%
df_tesla['Open'].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:10 days rolling']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla[['Open','Open:10 days rolling']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(window=30,min_periods=1).mean()
df_tesla['Open:50 days rolling']=df_tesla['Open'].rolling(window=50,min_periods=1).mean()

# %%
df_tesla[['Open','Open:10 days rolling','Open:30 days rolling','Open:50 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#cumulative moving average

# %%
## Expanding

df_tesla['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## EWMA - Exponential Moving Average

# %%
## EMA tesla share
# Let smoothning factor - 0.1
df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## EMA tesla share
# Let smoothning factor - 0.1
df_tesla['EMA_5days'] = df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open','EMA_0.1','EMA_5days']].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>
